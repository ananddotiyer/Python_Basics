# %% [markdown]
# #### Problem1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem5
#
# What is the output of this code snippet?

# %%
s1 = {1,2,3,4,4,1,2}
s2 = {4,3,2,1}
l1 = [4,3,2,1]
l2 = [1,2,3,4,4,1,2]
print(list(s1)==l2)
print(set(l1)==s2)
print(s1==s2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem6
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem7
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem8
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem9
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem10
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem11
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem12
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem13
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem14
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem15
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem16
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem17
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem18
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem19
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem20
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem21
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem22
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem23
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem24
#
# ![image.png](attachment:image.png)
