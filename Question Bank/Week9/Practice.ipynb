# %% [markdown]
# #### Problem1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem5
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem6
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem7
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem8
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem8
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem9
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem10
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem11
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem12
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem13
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem14
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem15
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem16
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem17
#
# ![image.png](attachment:image.png)

# %%
#Common data for questions 18 and 19
f = open('file.txt', 'w')
f.write('list')
f.write('tuple')
f.write('set')
f.write('dictionary')
f.close()

# %% [markdown]
# #### Problem18
#
# How many lines are present in the file.txt at the end of the execution of the above code? It is a Numerical Answer Type (NAT) question.

# %% [markdown]
# #### Problem19
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Common data for questions 20-24
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem20
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem21
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem22
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem23
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem24
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 25 and 26 are based on scores_dataset.csv . The data is read into Pandas dataframe variable data_df . Assume pandas library is already imported into the program as pd .

# %% [markdown]
# #### Problem25
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem26
#
# ![image.png](attachment:image.png)
