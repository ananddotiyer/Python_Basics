# %% [markdown]
# #### Problem1
#
# Read the file file_1.txt .
#
# - Print the contents of the file, one line at a time.
# - Print the type of the variable used to store the contents of each line in the file. Is it int , str , float or something entirely different?
# - Find the number of lines in the file.

# %% [markdown]
# #### Problem2
#
# The file file_2.txt is a collection of integers, one on each line. Read the file and print the sum of
# all the integers in it.

# %% [markdown]
# #### Problem3
#
# The file file_3.txt captures the maximum temperature recorded in Mumbai on every day during the month of May, 2021. Find the average temperature for the month.
#
# Note: Data is not accurate.

# %% [markdown]
# #### Problem4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem5
#
# The file file_4.txt has a number of sentences on each line. Each sentence is made of certain number of words. There are no punctuation marks. All words are in lower case. With this information, answer the following questions:
#
# - Find the number of sentences in the file.
# - Find the number of words in each sentence.
# - Find the sentence with the maximum number of words in it
# - Find the frequency of occurrence of words in the file.
# - Find the set of unique words used in the file.

# %% [markdown]
# #### Problem6
#
# file_5.txt is a text file that stores an m x n matrix. Each line represents one row of a matrix. Adjacent numbers are separated by a space. Write a code to extract the contents of the file and store in a matrix A . What is the dimension of the matrix?

# %% [markdown]
# #### Problem7
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem8
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem9
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem10
#
# Consider the file file_5.txt that was discussed in problem-6. Create a file file_9.txt , where each line contains one number from the matrix given in file_5.txt . Proceed row-wise, left to right and top to bottom: fetch one number at a time from the first row of the matrix and write it to the file. Each line in the file corresponds to exactly one entry in the matrix. Then move to the second row of the matrix and so on.

# %% [markdown]
# #### Problem11
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem12
#
# Write the student details from scores.csv into a file.  The file's header should be as follows:
#
# ![image.png](attachment:image.png)
