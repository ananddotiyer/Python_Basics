# %% [markdown]
# #### Problem 1

# %% [markdown]
# What are the basic data types that we have seen in this week?

# %% [markdown]
# #### Problem 2

# %% [markdown]
# How will the following objects be represented in Python?
#
# - email address
# - annual income
# - number of days in a month

# %% [markdown]
# #### Problem 3

# %% [markdown]
# In computer science, a bit is the short form of a binary digit. A bit can assume one of the two
# values: 0 and 1. What unites the following terms?
#
# - boolean
# - state of a switch
# - outcome of a coin toss
# - outcome of a tennis match
# - nodding your head

# %% [markdown]
# #### Problem 4

# %% [markdown]
# Find the last digit of 7^35

# %% [markdown]
# #### Problem 5

# %% [markdown]
# Find the remainder when 987654321 is divided by 123456789

# %% [markdown]
# #### Problem 6

# %% [markdown]
# Predict the output of the following lines.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem 7

# %% [markdown]
# Parenthesize this expression so that the result is zero.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem 8

# %% [markdown]
# Predict the output of the following expression.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem 9

# %% [markdown]
# If **some_string** is a string of length **n** , how many characters does **n * some_string** have, where **n** is some positive integer?

# %% [markdown]
# #### Problem 10

# %% [markdown]
# What will be the outcome of the following expression if **x** and **y** are two strings?
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem 11

# %% [markdown]
# What does the following code do? Is it syntactically correct?
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem 12

# %% [markdown]
# If the output of the following code snippet is 123 , what is the sequence of inputs entered by the user?
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem 13

# %% [markdown]
# Use Python as a calculator and find the square root of the number:12345678987654321.

# %% [markdown]
# #### Problem 14

# %% [markdown]
# Find the number of digits in 7^100.
#
# Treat this as a programming question and not as a mathematical question. You should be able to do this using the concepts that you have learned so far.

# %% [markdown]
# #### Problem 15

# %% [markdown]
# Accept a word as input. Assume that all characters in the word are in lower case. Print **True** if the first and last letter of the word are the same, and **False** otherwise. You should be able to do this using the concepts introduced in this week.
#
# Conditional statements can be used. They will be introduced in the next week. But the challenge is to solve this problem without using conditional statements! As an interesting exercise, can you list down some words that follow this pattern?

# %% [markdown]
# #### Problem 16

# %% [markdown]
# Accept a positive integer **x** as input from the user. Without using the * symbol anywhere in your code, print 10*x
# , i.e. the product of the integer input and the number 10.

# %% [markdown]
# #### Problem 17

# %% [markdown]
# Accept the length and breadth of a rectangle as input and compute its area.

# %% [markdown]
# #### Problem 18

# %% [markdown]
# What is the following code snippet trying to do? Try to relate this to the previous question.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem 19

# %% [markdown]
# What happens if the input is 1.23 for the program below? Execute and observe the output. Why do you think this is happening?
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem 20

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem 21

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem 22

# %% [markdown]
# Accept the score of a student in an exam as input. Print **True** if the student has scored between 90 and 100 , both endpoints included, and **False** otherwise. You can assume that the score is an integer.

# %% [markdown]
# #### Problem 23

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem 24

# %% [markdown]
# Accept a two digit number as input and print the sum of its digits. What about a three digit number?

# %% [markdown]
# #### Problem 25

# %% [markdown]
# Accept a positive integer as input and print **True** if it is a perfect square and **False** otherwise. For example, if the input is **25**, then you must print **True**. If the input is **15**, then you must print **False**
