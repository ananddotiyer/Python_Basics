# %% [markdown]
# #### Problem1
#
# What will be output of the following code snippet, if the input is **1234**

# %%
a, b, c, d = input()

print(a)
print(b)
print(c)
print(d)

# %% [markdown]
# #### Problem2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Use the following code to answer questions 4, 5 and 6.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem5
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem6
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem7
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Use the following code to answer questions 8, 9, 10 and 11.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem8
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem9
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem10
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem11
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem12
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem13
#
# What should be input to following code to get the below output?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem14
#
# ![image.png](attachment:image.png)
