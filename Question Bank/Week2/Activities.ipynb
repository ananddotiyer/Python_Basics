# %% [markdown]
# #### Problem1
#
# Execute the following code and observe how the type changes dynamically:

# %%
a = 1
print(type(a))

a = 1.
print(type(a))

a = '1'
print(type(a))

# %% [markdown]
# #### Problem2
#
# What will be the output when the following code-snippet is executed? Try to predict the answer before executing.

# %%
x, y, z = 3, 4, 5
x, y, z = x ** 2, y ** 2, z ** 2
print(x + y == z)

# %% [markdown]
# #### Problem3
#
# What will happen when the following code is executed? Try to predict the answer before executing.

# %%
good_variable = 10
a_ = 1
_a = 2
1_a = 10
is = 10
bad variable = 100

# %% [markdown]
# #### Problem4
#
# Execute the following code and observe the output. What do you think is happening here?

# %%
x, y = 1, 2
print(x, y)

x, y = y, x
print(x, y)

# %% [markdown]
# #### Problem5
#
# Will this code ever print second?

# %%
if True:
    print('first')
else:
    print('second')

# %% [markdown]
# #### Problem6
#
# What is the difference between the two snippets shown here? Are they functionally equivalent?

# %%
#first
x = True
if x == True:
    print('works')

# %%
#second
x = True
if x:
    print('works')

# %% [markdown]
# #### Problem7
#
# What is wrong with the following piece of code? If there are errors, modify the code so that it becomes error-free. What is this code trying to do?

# %%
x = input()
if x % 10 == 0:
    print('multiple of 10')
else:
    print('neither a multiple of 5 nor a multiple of 10')
elif (x % 5 == 0) and (x % 10 != 0):
    print('multiple of 5 and not a multiple of 10')

# %% [markdown]
# #### Problem8
#
# What is the following code trying to do? The idea is to take the help of the variable names and the rest of the code to figure out what is happening

# %%
year = int(input())
if year % 4 == 0:
    print('leap')
else:
    print('non-leap')

# %% [markdown]
# #### Problem9
#
# The following code accepts three sides of a triangle as input from the user and determines if the triangle is equilateral, isosceles or scalene. Assume that all three sides of the triangle are integers. Is something wrong with the code?

# %%
x, y, z = int(input()), int(input()), int(input())
if x == y and y == z:
    print('equilateral')
elif x == y and x != z:
    print('isoceles')
elif x == z and x != y:
    print('isoceles')
else:
    print('scalene')

# %% [markdown]
# #### Problem10
#
# Accept an integer x as input from the user. If the number is even, print even . If the number is odd, print odd.

# %% [markdown]
# #### Problem11
#
# Accept an integer x as input from the user and print the last digit of the number in English. Use the following table for reference.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem12
#
# Accept three integers as input from the user. Print good triplet if one of the three numbers is the sum of the other two, and bad triplet otherwise.

# %% [markdown]
# #### Problem13
#
# Accept three non-negative real numbers as input from the user. If the three numbers form the sides of a triangle, print True . If not, print False.

# %% [markdown]
# #### Problem14
#
# Accept four distinct integers as input from the user. Print in ascending order if the four numbers have been entered in ascending order, and print not in ascending order otherwise

# %% [markdown]
# #### Problem15
#
# On what day of the week were you born? If you don't know the answer to this, use the calendar library to get the answer.

# %% [markdown]
# #### Problem16
#
# The following string is encoded using the Caesar cipher with a shift of 5: **udymts** . Decode the string!

# %% [markdown]
# #### Problem17
#
# Consider the following snippet of code. What do you expect the output to be?

# %%
empty = ''
if empty:
    print('if')
else:
    print('else')

# %%
#Compare above snippet with the following one:
zero = 0
if zero:
    print('if')
else:
    print('else')

# %% [markdown]
# #### Problem18
#
# What is the difference in the output between the second and third line?

# %%
import math
print(2 ** 5)
print(math.pow(2, 5))

# %% [markdown]
# #### Problem19
#
# How many lines do you expect in the output between the strings **before** and **after** ?

# %%
print('before')
print('\n')
print('after')

# %% [markdown]
# #### Problem20
#
# A three digit number is called a **sandwich** number if the difference between its first and last digit is equal to its middle digit. Accept a three digit number as input and print **sandwich** if the number is a sandwich number. Print **plain** if the number is not a sandwich number. For example, **123** and **853** are sandwich numbers.

# %% [markdown]
# #### Problem21
#
# Consider the following message in SMS-speak.
#
# message = 'Txt me when u receive this msg.'
#
# Using string methods, convert the above message into the following form:
#
# Text me when you receive this message.

# %% [markdown]
# #### Problem22
#
# Accept a sentence as input and find the number of words in it. Assume that the sentence has no punctuation marks. For example:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem23
#
# Accept a paragraph as input and find the number of sentences in it. Assume that full stops are the only sentence breaks. All other punctuation marks can be ignored. For example:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem24
#
# A data entry operator at a telephone exchange is using a faulty keyboard — the zero key is missing — to enter phone numbers into an application. As a workaround, he uses the capital letter "O" wherever there is a zero in the phone number. Write a program to accept one of these phone numbers and convert all the "O"s to zeros. In the next week, we will see how to fix all the phone numbers with few more lines of code.

# %% [markdown]
# #### Problem25
#
# Consider the decimal expansion of the number 3^100. How many times does the digit 3 appear? Is there any digit that never appears in the expansion? Strings may come in handy here.

# %% [markdown]
# #### Problem26
#
# What do you think is the answer of the following code snippet? Do you see any \n in the string? Explain.

# %%
lines = '''one
two
three'''
print('\n' in lines)
print(lines.count('\n'))

# %% [markdown]
# #### Problem27
#
# Use the math library to compute the following function:
#
# ![image.png](attachment:image.png)
#
# Here **e** is the mathematical constant called the Euler number. **σ(x)** is an example of a "sigmoid function".

# %% [markdown]
# #### Problem28
#
# What is the difference between the string methods find and index ?

# %% [markdown]
# #### Problem29
#
# If a and b are two strings, what can you say about the value of the expressions in lines 1 and 2?

# %%
a = 'first'
b = 'second'

print((a in b) or (b in a))
print((a in b) or (a not in b))

# %% [markdown]
# #### Problem30
#
# What do you think is happening in the following code snippet?

# %%
import random
alpha = 'HT'

toss = random.choice(alpha)
print(toss)

# %% [markdown]
# #### Problem31
#
# Consider the following image of a chess board:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Accept two positions as input: start and end . Determine if a bishop at start can move to end . For example:
#
# ![image.png](attachment:image.png)
#
# Use the function **abs** to get the absolute value of an integer, if requiered.

# %% [markdown]
# #### Problem32
#
# You have n gold coins with you. You wish to divide this among two of your friends under the following conditions:
#
# - Both of them should get a non-zero share.
# - Both of them should end up with an even number of coins.
#
# Accept the value of n and determine if you can divide it among your two friends. Print YES if you can and NO if you can't.

# %% [markdown]
# #### Problem33
#
# You are given the results of a sequence of ODI matches played by India. A win is represented by 'W' and a loss is represented by 'L' . A winning streak is a string of consecutive wins. The outcomes are represented by a single string. If India has played five matches, then the string could look like this — 'WLWWW' . Answer the following questions:
#
# - Find the number of matches played by India.
# - How many matches has it won?
# - Does it have a three-match winning streak?
# - What is the first match that it has won?

# %% [markdown]
# #### Problem34
#
# In spreadsheets, columns are labeled as follows:
# First 26 columns correspond to the letters A to Z.
# The 27th column is represented by AA, 28th by AB and so on.
#
# You are given a column label as input. Your task is to determine the column number. Example inputs follow:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem35
#
# Accept a string as input. Print valid if it is a valid name and invalid if it is not a valid name. A name is valid if it doesn't contain any numbers or special characters.
