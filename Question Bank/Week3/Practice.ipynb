# %% [markdown]
# #### Problem1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem5
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem6
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem7
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem8
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem9
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem10
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem11
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem12
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem13
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem14
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem15
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem16
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem17
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem18
#
# ![image.png](attachment:image.png)
