# %% [markdown]
# #### Problem1
#
# Write a program to print the numbers which are divisible by 12 and 13 in range of [1000 - 2000]

# %% [markdown]
# #### Problem2
#
# Write a program to find the sum of the digits of the number got from the user.

# %% [markdown]
# #### Problem3
#
# Write a program to find sum of all prime numbers between 1 to n , where n is a positive integer
# from user.

# %% [markdown]
# #### Problem4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem5
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem6
#
# Accept two strings from the user and remove all characters from the second string which are
# present in the first string.

# %% [markdown]
# #### Problem7
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem8
#
# Write a program to find all the prime factors of a number which taken as input from user. Assume
# the accepted input as positive integer which is greater than or equal to 2.

# %% [markdown]
# #### Problem9
#
# Accept a string as an input from the user, convert this to lower case and print the string in ascending order using loop.
#
# Note: Ignore non-alphabetic characters in the output

# %% [markdown]
# #### Problem10
#
# Accept the string from the user and display the characters located on prime index (2,3,5,7..) of a given string.

# %% [markdown]
# #### Problem11
#
# Accept phone number from user as string.  A valid phone number should satisfy the following constraints.
#
# - The number should start with 6,7,8 and 9.
# - Length of the number should be 10.
# - Number should not have any digit repeated more then 5 times in consecutive manner.
# - Number should not have any digit more than 7 times.
