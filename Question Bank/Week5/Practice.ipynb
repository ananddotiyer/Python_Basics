# %% [markdown]
# #### Problem1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem2
#
# ![image.png](attachment:image.png)

# %%
# Common data for problem 3 and 4

def fact(n):
    if(n == 0):
        return 1
    else:
        return XXXXX

# %% [markdown]
# #### Problem3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem4
#
# How many times will the function fact be called for computing the factorial of 10? It is a Numerical Answer Type (NAT) Question.

# %% [markdown]
# #### Common data for problem 5 and 6
#
# Observe the following definitions for the function named display_sum . The purpose of this function is to display the sum of the numbers passed as arguments to it.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem5
#
# Which of the above function definitions are invalid. It is a Multiple Select Question(MSQ).

# %% [markdown]
# #### Problem6
#
# Which of the above definitions print the correct answer for display_sum(10,10) . It is a Multiple Select Question(MSQ).

# %% [markdown]
# #### Problem7
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem8
#
# What does the following code snippet print?

# %%
x = 10
y = 20
z = 30

def show(x,y):
    print(x + y + z)
    x = 40
    y = 50
    print(x + y + z)

show(100,300)
print(x + y + z)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem9
#
# Which positive integer input from the user will make this program display 264 as the output? It is a Numerical Answer Type (NAT) Question.

# %%
def func(x):
    return x + 1

n = int(input())
print(int(func(n / 2) * func(n + 1)))

# %% [markdown]
# #### Problem10
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem11
#
# Which positive integer input n from the user will make this program print 120?  It is a Numerical Answer Type (NAT) Question.

# %%
x = 10
y = 20
z = 30

def show(z):
    global x , y
    x = 40
    y = z
    z = 60

n = int(input())
show(n)
print(x + y + z)

# %% [markdown]
# #### Problem12
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem13
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem14
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem15
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem16
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem17
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem18
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem19
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem20
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem21
#
# Refer https://docs.python.org/3/library/math.html#math.hypot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem22
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem23
#
# ![image.png](attachment:image.png)
