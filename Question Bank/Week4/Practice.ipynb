# %% [markdown]
# #### Problem1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem5
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem6
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem7
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem8
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem9
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem10
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Common data for problems 11 and 12

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem11
#
# If flag is True at the end of execution of the code given above, which of the following statements are true? Note that the options should be true for any list L that satisfies the conditions given in the common data. Multiple options could be correct.
#
# - y is an element in the list L
# - y is the smallest number in the list
# - y is the greatest number in the list
# - y is the average (arithmetic mean) of the numbers in the list
# - y is the element at index len(L) // 2 in the list L

# %% [markdown]
# #### Problem12
#
# Assume that L is a list of the first positive integers, where n > 0. Under what conditions will the variable flag be True at the end of execution of the code given above?
#
# - n is an odd integer
# - n is an even integer

# %% [markdown]
# #### Problem13
#
# Assume that L is a list of the first positive integers, where n > 0. Under what conditions will the variable flag be True at the end of execution of the code given above?
#
# - n is an odd integer
# - n is an even integer

# %% [markdown]
# #### Problem14
#
# Write code to compute the dot product of a given vector with itself.
